# %%
import os
from dataclasses import dataclass

# %%
from dataclasses import dataclass

# %%
# %pwd
# Out:
# 'c:\\Users\\praba\\Documents\\Prabal\\Content-Summarizer\\Text-Summarizer\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\praba\\Documents\\Prabal\\Content-Summarizer\\Text-Summarizer'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen = True)
class DataIngestionConfig:
    root_dir : Path
    source_Url : str
    local_data_file : Path
    unzip_dir : Path

# %%
from textSummarizer.constants import *
from textSummarizer.utils.common import read_yaml , create_directories
# Out:
# C:\Users\praba\Documents\Prabal\Content-Summarizer\Text-Summarizer\src\textSummarizer\constants\__init__.py:3: SyntaxWarning: invalid escape sequence '\c'
#   CONFIG_FILE_PATH = Path("config\config.yaml")

# %%
class ConfigurationManager:
    def __init__(
            self,
            config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
